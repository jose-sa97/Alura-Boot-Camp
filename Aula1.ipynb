# %% [markdown]
# # Conhecendo a base e o problema
#
# 1) Base de farmácia com célular infectadas por um droga
#
# 2) Endereço do arquivo C:/Users/José Mateus/Documents/Imersão dados - Alura/imersaodados3/dados/dados_experimentos.csv

# %%
#1 Importando biblioteca pandas 

import pandas as pd 
import matplotlib.pyplot as plt

# %%
#2 Puxando e conhecendo a base

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

df = pd.read_csv(url_dados, compression = 'zip')

# %%
#3 Visão geral da base
df
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 0      id_000644bb2     com_droga     24   D1  b68db1d53  1.0620  0.5577
# 1      id_000779bfc     com_droga     72   D1  df89a8e5a  0.0743  0.4087
# 2      id_000a6266a     com_droga     48   D1  18bb41b2c  0.6280  0.5817
# 3      id_0015fd391     com_droga     48   D1  8c7f86626 -0.5138 -0.2491
# 4      id_001626bd3     com_droga     72   D2  7cbed3131 -0.3254 -0.4009
# ...             ...           ...    ...  ...        ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# ...

# %%
#4 Visão resumida da base
df.head()
# Out:
#              id tratamento  tempo dose      droga     g-0     g-1     g-2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#       g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94    c-95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#      c-96    c-97    c-98    c-99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# ## Desafio 1 - Por que a classe tratamento é tão desbalanceada?

# %%
# 1 Verificando a proporção entre as classes
df['tratamento'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# É visível que a classe não está balanceada, a causa disso pode ser diversa, depende do que motivou esse estudo.

# %% [markdown]
# ## Desafio 2 - Plotar 5 últimas linhas da base

# %%
df[-5:]
# Out:
#                  id    tratamento  tempo dose      droga     g-0     g-1  \
# 23809  id_fffb1ceed     com_droga     24   D2  df1d0a5a1  0.1394 -0.0636
# 23810  id_fffb70c0c     com_droga     24   D2  ecf3b6b74 -1.3260  0.3478
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324
# 23813  id_ffffdd77b     com_droga     72   D1  972f41291 -0.8598  1.0240
#
#           g-2     g-3     g-4  ...    c-90    c-91    c-92    c-93    c-94  \
# 23809 -0.1112 -0.5080 -0.4713  ...  0.1969  0.0262 -0.8121  0.3434  0.5372
# 23810 -0.3743  0.9905 -0.7178  ...  0.4286  0.4426  0.0423 -0.3195 -0.8086
# 23811  0.3109 -0.7389  0.5505  ...  0.5409  0.3755  0.7343  0.2807  0.4116
# 23812  0.4392  0.2044  0.8531  ... -0.1105  0.4258 -0.2012  0.1506  1.5230
# 23813 -0.1361  0.7952 -0.3611  ... -3.3890 -1.7450 -6.6300 -4.0950 -7.3860
#
#          c-95    c-96    c-97    c-98    c-99
# ...

# %% [markdown]
# ## Desafio 3 - Proporção das classes de tratamento

# %%
# 1 Verificando a proporção entre as classes
df['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# 92% da base foi tratada com droga

# %% [markdown]
# ## Desafio 4 - Quantos tipos de drogas foram utilizados?

# %%
df['droga'].nunique()
# Out:
# 3289

# %%
Existem 3289 tipos de drogas

# %% [markdown]
# ## Desafio 5 - Procurar na documentção query(pandas)

# %% [markdown]
# Link da doucumentção query(pandas)=https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html
#
# Como usar? https://medium.com/horadecodar/como-usar-o-query-do-pandas-fdf4a00727dc

# %%
#1 Aplicação
# Selecionar a base apenas onde g-0 é maior que 0
df.rename(columns=lambda x: x.replace('-', ''), inplace=True)
df.query('g0>0').iloc[1::1000]
# Out:
#                  id tratamento  tempo dose      droga      g0      g1      g2  \
# 1      id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2021   id_15cf05552  com_droga     24   D1  37b33b4d6  0.0595  0.4944  1.5430
# 4078   id_2bbbe9688  com_droga     48   D1  e160a2b00  0.5436 -0.2154  2.3800
# 6098   id_41a01517e  com_droga     48   D2  9307b7820  0.0156  0.3449 -0.7139
# 8076   id_56877051c  com_droga     24   D2  ba87a83c2  0.8548 -0.2936  0.0239
# 10118  id_6cf1d4f62  com_droga     48   D1  8b87a7a83  0.6385 -0.8824  1.4110
# 12100  id_823baa875  com_droga     72   D1  77be6d446  0.1962 -0.5057  0.7111
# 14071  id_97815077d  com_droga     48   D1  ce1dd3f87  0.1997 -0.2840  0.1218
# 16155  id_adc5afdb7  com_droga     72   D2  7d70427d6  0.3843 -1.0020 -0.2405
# 18214  id_c38ebbd15  com_droga     24   D2  a7c5f52df  0.6757  0.7443 -0.3049
# 20207  id_d8ec0216f  com_droga     48   D1  eb2f04575  1.4850 -1.3760  1.4030
# ...

# %% [markdown]
# ## Desafio 6 - Renomear as colunas tirando o hífen

# %%
df.rename(columns=lambda x: x.replace('-', ''), inplace=True)
df.head()
# Out:
#              id tratamento  tempo dose      droga      g0      g1      g2  \
# 0  id_000644bb2  com_droga     24   D1  b68db1d53  1.0620  0.5577 -0.2479
# 1  id_000779bfc  com_droga     72   D1  df89a8e5a  0.0743  0.4087  0.2991
# 2  id_000a6266a  com_droga     48   D1  18bb41b2c  0.6280  0.5817  1.5540
# 3  id_0015fd391  com_droga     48   D1  8c7f86626 -0.5138 -0.2491 -0.2656
# 4  id_001626bd3  com_droga     72   D2  7cbed3131 -0.3254 -0.4009  0.9700
#
#        g3      g4  ...     c90     c91     c92     c93     c94     c95  \
# 0 -0.6208 -0.1944  ...  0.2862  0.2584  0.8076  0.5523 -0.1912  0.6584
# 1  0.0604  1.0190  ... -0.4265  0.7543  0.4708  0.0230  0.2957  0.4899
# 2 -0.0764 -0.0323  ... -0.7250 -0.6297  0.6103  0.0223 -1.3240 -0.3174
# 3  0.5288  4.0620  ... -2.0990 -0.6441 -5.6300 -1.3780 -0.8632 -1.2880
# 4  0.6919  1.4180  ...  0.0042  0.0048  0.6670  1.0690  0.5523 -0.3031
#
#       c96     c97     c98     c99
# 0 -0.3981  0.2139  0.3801  0.4176
# ...

# %% [markdown]
# As colunas foram renomeadas aplicando-se a função lambda para remover o hífen das colunas

# %% [markdown]
# ## Desafio 7 - Deixar os gráficos bonitões

# %%
x=df['tratamento'].unique()
y=df['tratamento'].value_counts()

plt.figure(figsize=(10, 5))
plt.bar(x,y,color='red')
plt.xlabel('Tratamento')
plt.title('Propoção de células por tipo de tratamento')
#plt.grid(True)
# Out:
# Text(0.5, 1.0, 'Propoção de células por tipo de tratamento')

# %% [markdown]
# ## Desafio 8 - Resumo do que foi aprendido

# %% [markdown]
# ### Nessa primeira aula o aprendizado se baseou em:
#
# 1) Importar arquivos e exploração inicial da base
#
# 2) Funcções básicas para trabalhar com dataframe
#
# 3) Resolver alguns aplicando SQL
#
# 4) Aprender o básico da biblioteca Matlab
